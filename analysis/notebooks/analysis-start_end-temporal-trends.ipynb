# %% [markdown]
# # Local Row-level Model Temporal Trend Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lets load in the raw prediction data for a single model with binning that includes timestamps
# We can use the predictions.parquet file which is used for the R analysis script to generate the plots

# %%
path = '/Users/adamsorrenti/Documents/GitHub/lock-pred/analysis/data/exp-30-naive-sorted-row-locks/predictions.parquet'
# Load the data
df = pd.read_parquet(path)
# Check the data
print(df.head())
# Check the columns
print(df.columns)
# Check the shape
print(df.shape)
# Check the dtypes
print(df.dtypes)
# check the info
print(df.info())
# Out:
#         in_lock_sequences_id   in_lock_start_time     in_lock_end_time  \
# 282891                 38013  1734442173000604000  1734442173000612000
# 282892                 38014  1734442173000604000  1734442173000616000
# 282893                 38015  1734442173000605000  1734442173000624000
# 282894                 38016  1734442173000605000  1734442173000629000
# 282895                 38017  1734442173000606000  1734442173000655000
#
#          gt_lock_start_time     gt_lock_end_time        model  \
# 282891  1734442173000615000  1734442173000616000  transformer
# 282892  1734442173000623000  1734442173000624000  transformer
# 282893  1734442173000628000  1734442173000629000  transformer
# 282894  1734442173000646000  1734442173000655000  transformer
# 282895  1734442173000647000  1734442173000655000  transformer
#
#                                  data  train_data_percent_used  epochs  \
# 282891  data/fixed/row_sep/ORDERS.csv                      1.0      30
# 282892  data/fixed/row_sep/ORDERS.csv                      1.0      30
# 282893  data/fixed/row_sep/ORDERS.csv                      1.0      30
# 282894  data/fixed/row_sep/ORDERS.csv                      1.0      30
# 282895  data/fixed/row_sep/ORDERS.csv                      1.0      30
#
#         batch_size  ...  checkpoint  save_times_exit  args_file  \
# 282891          32  ...       False            False       None
# 282892          32  ...       False            False       None
# 282893          32  ...       False            False       None
# 282894          32  ...       False            False       None
# 282895          32  ...       False            False       None
#
#                                    unique_id  horizon_position gt_table  \
# 282891  6db89df3-5b1a-478b-82ab-37157041e71d                 1   orders
# 282892  1c8a9b58-bd83-4334-ae17-b905b7ac0190                 1   orders
# 282893  0ef88314-cdb9-4bc1-900b-966406fb0f1d                 1   orders
# 282894  a8334589-901b-4787-a9c6-b852d7b480ae                 1   orders
# 282895  33b4b743-4898-4397-a2f8-cb110b4cfd95                 1   orders
#
#         gt_pageid pred_table pred_pageid  iteration
# 282891       3426     orders        3931          1
# 282892       3426     orders        3426          1
# 282893       3426     orders        3426          1
# 282894       3565     orders        3426          1
# 282895       3566     orders        3565          1
#
# [5 rows x 44 columns]
# Index(['in_lock_sequences_id', 'in_lock_start_time', 'in_lock_end_time',
#        'gt_lock_start_time', 'gt_lock_end_time', 'model', 'data',
#        'train_data_percent_used', 'epochs', 'batch_size', 'learning_rate',
#        'seq_length', 'test_split', 'val_split', 'vocab_size', 'tokenization',
#        'patience', 'results_dir', 'experiment_name', 'horizon',
#        'model_weights', 'sort_by', 'shuffle', 'add_start_end_tokens',
#        'add_row_id', 'add_label_tokens', 'disable_train_shuffle',
#        'early_stopping', 'remove_system_tables', 'token_length_seq', 'lstm_pe',
#        'naive_baseline', 'disable_cache', 'shuffle_train', 'checkpoint',
#        'save_times_exit', 'args_file', 'unique_id', 'horizon_position',
#        'gt_table', 'gt_pageid', 'pred_table', 'pred_pageid', 'iteration'],
#       dtype='object')
# (10444264, 44)
# in_lock_sequences_id         int64
# in_lock_start_time           int64
# in_lock_end_time             int64
# gt_lock_start_time           int64
# gt_lock_end_time             int64
# model                       object
# data                        object
# train_data_percent_used    float64
# epochs                       int64
# batch_size                   int64
# learning_rate              float64
# seq_length                   int64
# test_split                 float64
# val_split                  float64
# vocab_size                   int64
# tokenization                object
# patience                     int64
# results_dir                 object
# experiment_name             object
# horizon                      int64
# model_weights               object
# sort_by                     object
# shuffle                       bool
# add_start_end_tokens          bool
# add_row_id                    bool
# add_label_tokens              bool
# disable_train_shuffle         bool
# early_stopping                bool
# remove_system_tables          bool
# token_length_seq              bool
# lstm_pe                       bool
# naive_baseline                bool
# disable_cache                 bool
# shuffle_train                 bool
# checkpoint                    bool
# save_times_exit               bool
# args_file                   object
# unique_id                   object
# horizon_position             int64
# gt_table                    object
# gt_pageid                    int64
# pred_table                  object
# pred_pageid                 object
# iteration                    int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 10444264 entries, 282891 to 20734271
# Data columns (total 44 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   in_lock_sequences_id     int64
#  1   in_lock_start_time       int64
#  2   in_lock_end_time         int64
#  3   gt_lock_start_time       int64
#  4   gt_lock_end_time         int64
#  5   model                    object
#  6   data                     object
#  7   train_data_percent_used  float64
#  8   epochs                   int64
#  9   batch_size               int64
#  10  learning_rate            float64
#  11  seq_length               int64
#  12  test_split               float64
#  13  val_split                float64
#  14  vocab_size               int64
#  15  tokenization             object
#  16  patience                 int64
#  17  results_dir              object
#  18  experiment_name          object
#  19  horizon                  int64
#  20  model_weights            object
#  21  sort_by                  object
#  22  shuffle                  bool
#  23  add_start_end_tokens     bool
#  24  add_row_id               bool
#  25  add_label_tokens         bool
#  26  disable_train_shuffle    bool
#  27  early_stopping           bool
#  28  remove_system_tables     bool
#  29  token_length_seq         bool
#  30  lstm_pe                  bool
#  31  naive_baseline           bool
#  32  disable_cache            bool
#  33  shuffle_train            bool
#  34  checkpoint               bool
#  35  save_times_exit          bool
#  36  args_file                object
#  37  unique_id                object
#  38  horizon_position         int64
#  39  gt_table                 object
#  40  gt_pageid                int64
#  41  pred_table               object
#  42  pred_pageid              object
#  43  iteration                int64
# dtypes: bool(14), float64(4), int64(14), object(12)
# memory usage: 2.5+ GB
# None

# %%
# Lets make sure we are sorted by the in_lock_start_time in ascending order
df = df.sort_values(by=['in_lock_start_time'])
df['in_lock_start_time'] = df['in_lock_start_time'] - df['in_lock_start_time'].min()  # center the time around 0

# %%
df['in_lock_start_time'].max(), df['in_lock_start_time'].min()
# Out:
# (337999657000, 0)

# %%
step_size = 1e10/4
num_plots = 4

# %%
# For storing key info for the final grid
plot_data = []

for i in range(num_plots):
    # Get the start and end time for the interval
    start_time = i * step_size
    end_time = (i + 1) * step_size

    # Get the data for the interval
    df_interval = df[(df['horizon'] == 1) & 
                     (df['iteration'] == 1) & 
                     (df['in_lock_start_time'] >= start_time) & 
                     (df['in_lock_start_time'] < end_time)]

    print(f'Interval {i}: {df_interval["gt_pageid"].nunique()} unique gt_pageid')
    print(f'Interval {i}: {df_interval["gt_pageid"].count()} gt_pageid')

    # Convert pred_pageid to numeric
    pred_pageid_numeric = pd.to_numeric(df_interval['pred_pageid'], errors='coerce').dropna()

    # Compute bins
    all_pageids = pd.concat([df_interval['gt_pageid'], pred_pageid_numeric])
    bins = np.histogram_bin_edges(all_pageids, bins=50)

    # Compute KL divergence
    epsilon = 1e-10
    gt_hist, _ = np.histogram(df_interval['gt_pageid'], bins=bins, density=True)
    pred_hist, _ = np.histogram(pred_pageid_numeric, bins=bins, density=True)
    gt_hist += epsilon
    pred_hist += epsilon
    kl_div = np.sum(gt_hist * np.log(gt_hist / pred_hist))
    #print(f'Interval {i}: KL divergence = {kl_div:.4f}')

    # Plot individually (inline)
    plt.figure(figsize=(6, 4))
    plt.hist(df_interval['gt_pageid'], bins=bins, alpha=0.5, label='gt_pageid')
   # plt.hist(pred_pageid_numeric, bins=bins, alpha=0.5, label='pred_pageid')
    plt.title(f'Interval {i} | {len(df_interval["gt_pageid"])} gt_pageid')
    plt.xlabel('Page ID')
    plt.ylabel('Freq')
    plt.ylim(0, 2_500)
    plt.xlim(0, 91_000)
    plt.legend()
    plt.show()

    # Store for final grid
    plot_data.append((df_interval['gt_pageid'], pred_pageid_numeric, bins, kl_div, i))


# Now plot all together in a grid
ncols = 2
nrows = int(np.ceil(num_plots / ncols))
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 6, nrows * 4))
axs = axs.flatten()

for idx, (gt_pageid, pred_pageid, bins, kl_div, i) in enumerate(plot_data):
    ax = axs[idx]
    ax.hist(gt_pageid, bins=bins, alpha=0.5, label='gt_pageid')
    #ax.hist(pred_pageid, bins=bins, alpha=0.5, label='pred_pageid')
    ax.set_title(f'Interval {i} | {len(gt_pageid)} gt_pageid')
    ax.set_xlabel('Page ID')
    ax.set_ylabel('Freq')
    ax.set_ylim(0, 2_500)
    ax.set_xlim(0, 91_000)
    ax.legend()

# Remove unused subplots
for j in range(len(plot_data), len(axs)):
    fig.delaxes(axs[j])

plt.tight_layout()
plt.show()
# Out:
# Interval 0: 543 unique gt_pageid
# Interval 0: 2864 gt_pageid
# Interval 1: 4681 unique gt_pageid
# Interval 1: 9649 gt_pageid
# Interval 2: 5331 unique gt_pageid
# Interval 2: 11394 gt_pageid
# Interval 3: 4729 unique gt_pageid
# Interval 3: 9921 gt_pageid

# %%
path = '/Users/adamsorrenti/Documents/GitHub/lock-pred/analysis/data/exp-31-lstm-sorted-row-locks'
# Load the data
df = pd.read_parquet(path)
# Lets make sure we are sorted by the in_lock_start_time in ascending order
df = df.sort_values(by=['in_lock_start_time'])
df['in_lock_start_time'] = df['in_lock_start_time'] - df['in_lock_start_time'].min()  # center the time around 0

# %%
# For storing key info for the final grid
plot_data = []

for i in range(num_plots):
    # Get the start and end time for the interval
    start_time = i * step_size
    end_time = (i + 1) * step_size

    # Get the data for the interval
    df_interval = df[(df['horizon'] == 1) & 
                     (df['iteration'] == 1) & 
                     (df['in_lock_start_time'] >= start_time) & 
                     (df['in_lock_start_time'] < end_time)]

    print(f'Interval {i}: {df_interval["gt_pageid"].nunique()} unique gt_pageid')
    print(f'Interval {i}: {df_interval["gt_pageid"].count()} gt_pageid')

    # Convert pred_pageid to numeric
    pred_pageid_numeric = pd.to_numeric(df_interval['pred_pageid'], errors='coerce').dropna()

    # Compute bins
    all_pageids = pd.concat([df_interval['gt_pageid'], pred_pageid_numeric])
    bins = np.histogram_bin_edges(all_pageids, bins=50)

    # Compute KL divergence
    epsilon = 1e-10
    gt_hist, _ = np.histogram(df_interval['gt_pageid'], bins=bins, density=True)
    pred_hist, _ = np.histogram(pred_pageid_numeric, bins=bins, density=True)
    gt_hist += epsilon
    pred_hist += epsilon
    kl_div = np.sum(gt_hist * np.log(gt_hist / pred_hist))
    #print(f'Interval {i}: KL divergence = {kl_div:.4f}')

    # Plot individually (inline)
    plt.figure(figsize=(6, 4))
    plt.hist(df_interval['gt_pageid'], bins=bins, alpha=0.5, label='gt_pageid')
   # plt.hist(pred_pageid_numeric, bins=bins, alpha=0.5, label='pred_pageid')
    plt.title(f'Interval {i} | {len(df_interval["gt_pageid"])} gt_pageid')
    plt.xlabel('Page ID')
    plt.ylabel('Freq')
    plt.ylim(0, 2_500)
    plt.xlim(0, 91_000)
    plt.legend()
    plt.show()

    # Store for final grid
    plot_data.append((df_interval['gt_pageid'], pred_pageid_numeric, bins, kl_div, i))


# Now plot all together in a grid
ncols = 2
nrows = int(np.ceil(num_plots / ncols))
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 6, nrows * 4))
axs = axs.flatten()

for idx, (gt_pageid, pred_pageid, bins, kl_div, i) in enumerate(plot_data):
    ax = axs[idx]
    ax.hist(gt_pageid, bins=bins, alpha=0.5, label='gt_pageid')
    #ax.hist(pred_pageid, bins=bins, alpha=0.5, label='pred_pageid')
    ax.set_title(f'Interval {i} | {len(gt_pageid)} gt_pageid')
    ax.set_xlabel('Page ID')
    ax.set_ylabel('Freq')
    ax.set_ylim(0, 2_500)
    ax.set_xlim(0, 91_000)
    ax.legend()

# Remove unused subplots
for j in range(len(plot_data), len(axs)):
    fig.delaxes(axs[j])

plt.tight_layout()
plt.show()
# Out:
# Interval 0: 543 unique gt_pageid
# Interval 0: 2864 gt_pageid
# Interval 1: 4681 unique gt_pageid
# Interval 1: 9649 gt_pageid
# Interval 2: 5331 unique gt_pageid
# Interval 2: 11394 gt_pageid
# Interval 3: 4729 unique gt_pageid
# Interval 3: 9921 gt_pageid
