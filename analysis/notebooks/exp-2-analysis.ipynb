# %%
import pandas as pd

def clean_data(df):
    # Filter rows based on column: 'model'
    df = df[df['model'] == "transformer"]
    # Drop columns: 'data', 'train_data_percent_used' and 15 other columns
    df = df.drop(columns=['data', 'train_data_percent_used', 'epochs', 'batch_size', 'learning_rate', 'seq_length', 'test_split', 'val_split', 'vocab_size', 'patience', 'results_dir', 'add_start_end_tokens', 'add_row_id', 'add_label_tokens', 'disable_train_shuffle', 'early_stopping', 'remove_system_tables'])
    # Sort by column: 'actual_test_accuracy_mean' (descending)
    df = df.sort_values(['actual_test_accuracy_mean'], ascending=[False])
    return df

# Loaded variable 'df' from URI: /root/github/lock-pred/results/exp-2/results_clean.csv
df = pd.read_csv('../results/exp-2/results_clean.csv')

df_clean = clean_data(df.copy())
df_clean
# Out:
#          model tokenization         experiment_name  horizon  shuffle  \
# 4  transformer         char    exp-2/shuffled_char_        1     True
# 5  transformer         char  exp-2/unshuffled_char_        1    False
# 6  transformer         word    exp-2/shuffled_word_        1     True
# 7  transformer         word  exp-2/unshuffled_word_        1    False
#
#    token_length_seq  actual_test_accuracy_mean  actual_test_accuracy_std  \
# 4              True                   0.837444                  0.006474
# 5              True                   0.777100                  0.018554
# 6              True                   0.724016                  0.011521
# 7              True                   0.027589                  0.004156
#
#    loss_mean  loss_std  accuracy_per_output_mean  accuracy_per_output_std  \
# 4   0.273229  0.016735                  0.945190                 0.003101
# 5   0.293383  0.007953                  0.937918                 0.002546
# 6   1.712718  0.129170                  0.814383                 0.008442
# 7   6.876404  0.296771                  0.494437                 0.001523
#
#    table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 4                       0.918112                      0.005233
# 5                       0.892502                      0.012878
# 6                       0.738354                      0.009797
# 7                       0.075215                      0.003742
#
#    pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 4                   0.853297                  0.006971
# 5                   0.811382                  0.017558
# 6                   0.890412                  0.010012
# 7                   0.913659                  0.002775
#
#    padding_test_accuracy_mean  padding_test_accuracy_std
# 4                    0.978997                   0.002661
# 5                    0.979359                   0.004040
# 6                         NaN                        NaN
# 7                         NaN                        NaN
