# %%
import pandas as pd

def clean_data(df):
    # Drop columns: 'data', 'epochs' and 12 other columns
    df = df.drop(columns=['data', 'epochs', 'batch_size', 'learning_rate', 'seq_length', 'test_split', 'val_split', 'vocab_size', 'patience', 'results_dir', 'shuffle', 'disable_train_shuffle', 'early_stopping', 'remove_system_tables'])
    # Sort by column: 'actual_test_accuracy_mean' (descending)
    df = df.sort_values(['actual_test_accuracy_mean'], ascending=[False])
    return df

df = pd.read_csv('../results/exp-5/results_clean.csv')

df_clean = clean_data(df.copy())

# %%
# for each train_data_percent_used, get the row with the highest actual_test_accuracy_mean
df_best_per_percent = df_clean.loc[df_clean.groupby('train_data_percent_used')['actual_test_accuracy_mean'].idxmax()]
df_best_per_percent.sort_values('train_data_percent_used', ascending=[False], inplace=True)
df_best_per_percent
# Out:
#           model  train_data_percent_used tokenization    experiment_name  \
# 37  transformer                      1.0         char  exp-5/char_se_lr_
# 29  transformer                      0.8         char  exp-5/char_se_lr_
# 21  transformer                      0.6         char  exp-5/char_se_lr_
# 13  transformer                      0.4         char  exp-5/char_se_lr_
# 5   transformer                      0.2         char  exp-5/char_se_lr_
#
#     horizon  add_start_end_tokens  add_row_id  add_label_tokens  \
# 37        1                  True       False              True
# 29        1                  True       False              True
# 21        1                  True       False              True
# 13        1                  True       False              True
# 5         1                  True       False              True
#
#     token_length_seq  actual_test_accuracy_mean  ...  loss_mean  loss_std  \
# 37              True                   0.869072  ...   0.248672  0.001709
# 29              True                   0.867698  ...   0.250896  0.001635
# 21              True                   0.869367  ...   0.255187  0.002201
# 13              True                   0.859401  ...   0.268334  0.002517
# 5               True                   0.493373  ...   0.406100  0.030548
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 37                  0.954580                 0.000153
# 29                  0.954409                 0.000420
# 21                  0.954546                 0.000161
# 13                  0.953510                 0.000665
# 5                   0.907997                 0.010799
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 37                       0.940599                      0.000000
# 29                       0.940599                      0.000000
# 21                       0.940501                      0.000207
# 13                       0.939175                      0.002643
# 5                        0.852283                      0.035738
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 37                   0.869072                  0.001269
# 29                   0.867698                  0.004199
# 21                   0.869465                  0.001577
# 13                   0.860825                  0.006644
# 5                    0.547079                  0.069573
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 37                         1.0                        0.0
# 29                         1.0                        0.0
# 21                         1.0                        0.0
# 13                         1.0                        0.0
# 5                          1.0                        0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
df_clean[df_clean['train_data_percent_used'] == 1.0].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 37  transformer                      1.0         char    exp-5/char_se_lr_
# 32  transformer                      1.0         char          exp-5/char_
# 33  transformer                      1.0         char       exp-5/char_lr_
# 36  transformer                      1.0         char       exp-5/char_se_
# 39  transformer                      1.0         char  exp-5/char_se_r_lr_
# 35  transformer                      1.0         char     exp-5/char_r_lr_
# 38  transformer                      1.0         char     exp-5/char_se_r_
# 34  transformer                      1.0         char        exp-5/char_r_
#
#     horizon  add_start_end_tokens  add_row_id  add_label_tokens  \
# 37        1                  True       False              True
# 32        1                 False       False             False
# 33        1                 False       False              True
# 36        1                  True       False             False
# 39        1                  True        True              True
# 35        1                 False        True              True
# 38        1                  True        True             False
# 34        1                 False        True             False
#
#     token_length_seq  actual_test_accuracy_mean  ...  loss_mean  loss_std  \
# 37              True                   0.869072  ...   0.248672  0.001709
# 32              True                   0.867682  ...   0.249134  0.001436
# 33              True                   0.866323  ...   0.249300  0.001741
# 36              True                   0.866078  ...   0.251663  0.002325
# 39              True                   0.833088  ...   0.272120  0.005701
# 35              True                   0.801375  ...   0.283284  0.006113
# 38              True                   0.763967  ...   0.308757  0.019990
# 34              True                   0.676583  ...   0.363080  0.012213
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 37                  0.954580                 0.000153
# 32                  0.954588                 0.000292
# 33                  0.954271                 0.000592
# 36                  0.954286                 0.000167
# 39                  0.950736                 0.001405
# 35                  0.946421                 0.002682
# 38                  0.940299                 0.005890
# 34                  0.925223                 0.003612
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 37                       0.940599                      0.000000
# 32                       0.940422                      0.002019
# 33                       0.939372                      0.002590
# 36                       0.940599                      0.000000
# 39                       0.928522                      0.004965
# 35                       0.933922                      0.003609
# 38                       0.920520                      0.004424
# 34                       0.880903                      0.006439
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 37                   0.869072                  0.001269
# 32                   0.868320                  0.001398
# 33                   0.867599                  0.003510
# 36                   0.866078                  0.001633
# 39                   0.842612                  0.010256
# 35                   0.805106                  0.021095
# 38                   0.774669                  0.038377
# 34                   0.697104                  0.018216
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 37                    1.000000                   0.000000
# 32                    1.000000                   0.000000
# 33                    1.000000                   0.000000
# 36                    1.000000                   0.000000
# 39                    1.000000                   0.000000
# 35                    0.999951                   0.000155
# 38                    1.000000                   0.000000
# 34                    1.000000                   0.000000
#
# [8 rows x 21 columns]

# %%
df_clean[df_clean['train_data_percent_used'] == 0.8].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 29  transformer                      0.8         char    exp-5/char_se_lr_
# 24  transformer                      0.8         char          exp-5/char_
# 28  transformer                      0.8         char       exp-5/char_se_
# 25  transformer                      0.8         char       exp-5/char_lr_
# 31  transformer                      0.8         char  exp-5/char_se_r_lr_
# 27  transformer                      0.8         char     exp-5/char_r_lr_
# 30  transformer                      0.8         char     exp-5/char_se_r_
# 26  transformer                      0.8         char        exp-5/char_r_
#
#     horizon  add_start_end_tokens  add_row_id  add_label_tokens  \
# 29        1                  True       False              True
# 24        1                 False       False             False
# 28        1                  True       False             False
# 25        1                 False       False              True
# 31        1                  True        True              True
# 27        1                 False        True              True
# 30        1                  True        True             False
# 26        1                 False        True             False
#
#     token_length_seq  actual_test_accuracy_mean  ...  loss_mean  loss_std  \
# 29              True                   0.867698  ...   0.250896  0.001635
# 24              True                   0.866847  ...   0.254304  0.002411
# 28              True                   0.864507  ...   0.256510  0.001464
# 25              True                   0.864016  ...   0.253417  0.001774
# 31              True                   0.802356  ...   0.291386  0.007260
# 27              True                   0.754836  ...   0.309642  0.015851
# 30              True                   0.735788  ...   0.322405  0.018003
# 26              True                   0.633088  ...   0.393076  0.016523
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 29                  0.954409                 0.000420
# 24                  0.954475                 0.000368
# 28                  0.954089                 0.000375
# 25                  0.953991                 0.000302
# 31                  0.946843                 0.002394
# 27                  0.939779                 0.005355
# 30                  0.936264                 0.005612
# 26                  0.916892                 0.004314
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 29                       0.940599                      0.000000
# 24                       0.940373                      0.002008
# 28                       0.940059                      0.001708
# 25                       0.940157                      0.000673
# 31                       0.923368                      0.005177
# 27                       0.930191                      0.004708
# 30                       0.912666                      0.007021
# 26                       0.870987                      0.010058
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 29                   0.867698                  0.004199
# 24                   0.867534                  0.003019
# 28                   0.865096                  0.003188
# 25                   0.864359                  0.002739
# 31                   0.813451                  0.018609
# 27                   0.760236                  0.039232
# 30                   0.748797                  0.035463
# 26                   0.654345                  0.022775
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 29                         1.0                        0.0
# 24                         1.0                        0.0
# 28                         1.0                        0.0
# 25                         1.0                        0.0
# 31                         1.0                        0.0
# 27                         1.0                        0.0
# 30                         1.0                        0.0
# 26                         1.0                        0.0
#
# [8 rows x 21 columns]

# %%
df_clean[df_clean['train_data_percent_used'] == 0.6].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 21  transformer                      0.6         char    exp-5/char_se_lr_
# 17  transformer                      0.6         char       exp-5/char_lr_
# 20  transformer                      0.6         char       exp-5/char_se_
# 16  transformer                      0.6         char          exp-5/char_
# 23  transformer                      0.6         char  exp-5/char_se_r_lr_
# 19  transformer                      0.6         char     exp-5/char_r_lr_
# 22  transformer                      0.6         char     exp-5/char_se_r_
# 18  transformer                      0.6         char        exp-5/char_r_
#
#     horizon  add_start_end_tokens  add_row_id  add_label_tokens  \
# 21        1                  True       False              True
# 17        1                 False       False              True
# 20        1                  True       False             False
# 16        1                 False       False             False
# 23        1                  True        True              True
# 19        1                 False        True              True
# 22        1                  True        True             False
# 18        1                 False        True             False
#
#     token_length_seq  actual_test_accuracy_mean  ...  loss_mean  loss_std  \
# 21              True                   0.869367  ...   0.255187  0.002201
# 17              True                   0.863721  ...   0.258789  0.001307
# 20              True                   0.859499  ...   0.264705  0.003317
# 16              True                   0.858890  ...   0.260784  0.003699
# 23              True                   0.741237  ...   0.320034  0.005934
# 19              True                   0.673294  ...   0.363239  0.021638
# 22              True                   0.609769  ...   0.395724  0.011004
# 18              True                   0.524202  ...   0.457375  0.014501
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 21                  0.954546                 0.000161
# 17                  0.953977                 0.000266
# 20                  0.953530                 0.000506
# 16                  0.953590                 0.000716
# 23                  0.938689                 0.002007
# 19                  0.924688                 0.005821
# 22                  0.915140                 0.004016
# 18                  0.895169                 0.004943
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 21                       0.940501                      0.000207
# 17                       0.939175                      0.001942
# 20                       0.940550                      0.000155
# 16                       0.938409                      0.004150
# 23                       0.916495                      0.006203
# 19                       0.919588                      0.007796
# 22                       0.901669                      0.012052
# 18                       0.857928                      0.006393
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 21                   0.869465                  0.001577
# 17                   0.865194                  0.002258
# 20                   0.859548                  0.004857
# 16                   0.861051                  0.005597
# 23                   0.753265                  0.017926
# 19                   0.680216                  0.025758
# 22                   0.621699                  0.026478
# 18                   0.541777                  0.025084
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 21                         1.0                        0.0
# 17                         1.0                        0.0
# 20                         1.0                        0.0
# 16                         1.0                        0.0
# 23                         1.0                        0.0
# 19                         1.0                        0.0
# 22                         1.0                        0.0
# 18                         1.0                        0.0
#
# [8 rows x 21 columns]

# %%
df_clean[df_clean['train_data_percent_used'] == 0.4].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 13  transformer                      0.4         char    exp-5/char_se_lr_
# 12  transformer                      0.4         char       exp-5/char_se_
# 8   transformer                      0.4         char          exp-5/char_
# 9   transformer                      0.4         char       exp-5/char_lr_
# 15  transformer                      0.4         char  exp-5/char_se_r_lr_
# 11  transformer                      0.4         char     exp-5/char_r_lr_
# 14  transformer                      0.4         char     exp-5/char_se_r_
# 10  transformer                      0.4         char        exp-5/char_r_
#
#     horizon  add_start_end_tokens  add_row_id  add_label_tokens  \
# 13        1                  True       False              True
# 12        1                  True       False             False
# 8         1                 False       False             False
# 9         1                 False       False              True
# 15        1                  True        True              True
# 11        1                 False        True              True
# 14        1                  True        True             False
# 10        1                 False        True             False
#
#     token_length_seq  actual_test_accuracy_mean  ...  loss_mean  loss_std  \
# 13              True                   0.859401  ...   0.268334  0.002517
# 12              True                   0.826019  ...   0.288556  0.005449
# 8               True                   0.814391  ...   0.286260  0.007207
# 9               True                   0.810702  ...   0.283139  0.005153
# 15              True                   0.585272  ...   0.406599  0.028212
# 11              True                   0.578694  ...   0.468632  0.010204
# 14              True                   0.476583  ...   0.525609  0.019567
# 10              True                   0.347865  ...   0.618679  0.028363
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 13                  0.953510                 0.000665
# 12                  0.950074                 0.001823
# 8                   0.949018                 0.002861
# 9                   0.948552                 0.002257
# 15                  0.912155                 0.009560
# 11                  0.901119                 0.003396
# 14                  0.881222                 0.007606
# 10                  0.851699                 0.010001
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 13                       0.939175                      0.002643
# 12                       0.940010                      0.001863
# 8                        0.931434                      0.005936
# 9                        0.933039                      0.011994
# 15                       0.892194                      0.009429
# 11                       0.886549                      0.009238
# 14                       0.870005                      0.014063
# 10                       0.812469                      0.015598
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 13                   0.860825                  0.006644
# 12                   0.826608                  0.018675
# 8                    0.823428                  0.028156
# 9                    0.817280                  0.014953
# 15                   0.597595                  0.054585
# 11                   0.586843                  0.018039
# 14                   0.486942                  0.029329
# 10                   0.367059                  0.048909
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 13                         1.0                        0.0
# 12                         1.0                        0.0
# 8                          1.0                        0.0
# 9                          1.0                        0.0
# 15                         1.0                        0.0
# 11                         1.0                        0.0
# 14                         1.0                        0.0
# 10                         1.0                        0.0
#
# [8 rows x 21 columns]

# %%
df_clean[df_clean['train_data_percent_used'] == 0.2].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#          model  train_data_percent_used tokenization      experiment_name  \
# 5  transformer                      0.2         char    exp-5/char_se_lr_
# 1  transformer                      0.2         char       exp-5/char_lr_
# 3  transformer                      0.2         char     exp-5/char_r_lr_
# 4  transformer                      0.2         char       exp-5/char_se_
# 0  transformer                      0.2         char          exp-5/char_
# 6  transformer                      0.2         char     exp-5/char_se_r_
# 7  transformer                      0.2         char  exp-5/char_se_r_lr_
# 2  transformer                      0.2         char        exp-5/char_r_
#
#    horizon  add_start_end_tokens  add_row_id  add_label_tokens  \
# 5        1                  True       False              True
# 1        1                 False       False              True
# 3        1                 False        True              True
# 4        1                  True       False             False
# 0        1                 False       False             False
# 6        1                  True        True             False
# 7        1                  True        True              True
# 2        1                 False        True             False
#
#    token_length_seq  actual_test_accuracy_mean  ...  loss_mean  loss_std  \
# 5              True                   0.493373  ...   0.406100  0.030548
# 1              True                   0.351694  ...   0.463940  0.049314
# 3              True                   0.252528  ...   0.709996  0.033829
# 4              True                   0.248454  ...   0.553361  0.079782
# 0              True                   0.224312  ...   0.566442  0.051359
# 6              True                   0.094845  ...   0.899839  0.053755
# 7              True                   0.072067  ...   0.918414  0.053062
# 2              True                   0.030388  ...   1.145773  0.052649
#
#    accuracy_per_output_mean  accuracy_per_output_std  \
# 5                  0.907997                 0.010799
# 1                  0.890128                 0.016812
# 3                  0.825405                 0.008329
# 4                  0.860913                 0.024546
# 0                  0.857750                 0.014073
# 6                  0.776382                 0.013778
# 7                  0.765984                 0.013505
# 2                  0.728159                 0.006164
#
#    table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 5                       0.852283                      0.035738
# 1                       0.816691                      0.050631
# 3                       0.824840                      0.020557
# 4                       0.925871                      0.009575
# 0                       0.844695                      0.056340
# 6                       0.795680                      0.031129
# 7                       0.839273                      0.022189
# 2                       0.709524                      0.021594
#
#    pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 5                   0.547079                  0.069573
# 1                   0.401276                  0.119086
# 3                   0.259352                  0.040835
# 4                   0.250859                  0.126589
# 0                   0.249607                  0.068151
# 6                   0.099411                  0.027357
# 7                   0.073196                  0.019834
# 2                   0.035297                  0.014214
#
#    padding_test_accuracy_mean  padding_test_accuracy_std
# 5                    1.000000                   0.000000
# 1                    1.000000                   0.000000
# 3                    1.000000                   0.000000
# 4                    1.000000                   0.000000
# 0                    1.000000                   0.000000
# 6                    1.000000                   0.000000
# 7                    1.000000                   0.000000
# 2                    0.999558                   0.000632
#
# [8 rows x 21 columns]
