# %%
import pandas as pd

def clean_data(df):
    # Drop columns: 'data', 'epochs' and 12 other columns
    df = df.drop(columns=['data', 'epochs', 'batch_size', 'learning_rate', 'seq_length', 'test_split', 'val_split', 'vocab_size', 'patience', 'results_dir', 'shuffle', 'disable_train_shuffle', 'early_stopping', 'remove_system_tables'])
    # Sort by column: 'actual_test_accuracy_mean' (descending)
    df = df.sort_values(['actual_test_accuracy_mean'], ascending=[False])
    return df

df = pd.read_csv('../results/exp-5-large/results_clean.csv')

df_clean = clean_data(df.copy())

# %%
# for each train_data_percent_used, get the row with the highest actual_test_accuracy_mean
df_best_per_percent = df_clean.loc[df_clean.groupby('train_data_percent_used')['actual_test_accuracy_mean'].idxmax()]
df_best_per_percent.sort_values('train_data_percent_used', ascending=[False], inplace=True)
df_best_per_percent
# Out:
#           model  train_data_percent_used tokenization  \
# 39  transformer                      1.0         char
# 31  transformer                      0.8         char
# 23  transformer                      0.6         char
# 12  transformer                      0.4         char
# 4   transformer                      0.2         char
#
#               experiment_name  add_start_end_tokens  add_row_id  \
# 39  exp-5-large/char_se_r_lr_                  True        True
# 31  exp-5-large/char_se_r_lr_                  True        True
# 23  exp-5-large/char_se_r_lr_                  True        True
# 12       exp-5-large/char_se_                  True       False
# 4        exp-5-large/char_se_                  True       False
#
#     add_label_tokens  token_length_seq  actual_test_accuracy_mean  \
# 39              True              True                   0.859281
# 31              True              True                   0.865182
# 23              True              True                   0.858350
# 12             False              True                   0.855098
# 4              False              True                   0.850478
#
#     actual_test_accuracy_std  loss_mean  loss_std  accuracy_per_output_mean  \
# 39                  0.011821   0.350523  0.007785                  0.940083
# 31                  0.008875   0.349441  0.006880                  0.941310
# 23                  0.009671   0.358756  0.005499                  0.939905
# 12                  0.002583   0.352106  0.015328                  0.940643
# 4                   0.005139   0.371217  0.012885                  0.938912
#
#     accuracy_per_output_std  table_name_test_accuracy_mean  \
# 39                 0.001698                       0.944125
# 31                 0.001308                       0.948364
# 23                 0.001276                       0.944747
# 12                 0.000707                       0.956672
# 4                  0.000938                       0.954270
#
#     table_name_test_accuracy_std  pageid_test_accuracy_mean  \
# 39                      0.009336                   0.868407
# 31                      0.003783                   0.870434
# 23                      0.004092                   0.866288
# 12                      0.002109                   0.855443
# 4                       0.002629                   0.851245
#
#     pageid_test_accuracy_std  padding_test_accuracy_mean  \
# 39                  0.009930                    0.989382
# 31                  0.008441                    0.989387
# 23                  0.008111                    0.989238
# 12                  0.002628                    0.989490
# 4                   0.005090                    0.988985
#
#     padding_test_accuracy_std
# 39                   0.000216
# 31                   0.000221
# 23                   0.000178
# 12                   0.000119
# 4                    0.000107

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
df_clean[df_clean['train_data_percent_used'] == 1.0].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization  \
# 39  transformer                      1.0         char
# 35  transformer                      1.0         char
# 32  transformer                      1.0         char
# 33  transformer                      1.0         char
# 36  transformer                      1.0         char
# 37  transformer                      1.0         char
# 38  transformer                      1.0         char
# 34  transformer                      1.0         char
#
#               experiment_name  add_start_end_tokens  add_row_id  \
# 39  exp-5-large/char_se_r_lr_                  True        True
# 35     exp-5-large/char_r_lr_                 False        True
# 32          exp-5-large/char_                 False       False
# 33       exp-5-large/char_lr_                 False       False
# 36       exp-5-large/char_se_                  True       False
# 37    exp-5-large/char_se_lr_                  True       False
# 38     exp-5-large/char_se_r_                  True        True
# 34        exp-5-large/char_r_                 False        True
#
#     add_label_tokens  token_length_seq  actual_test_accuracy_mean  \
# 39              True              True                   0.859281
# 35              True              True                   0.858098
# 32             False              True                   0.857933
# 33              True              True                   0.855242
# 36             False              True                   0.854934
# 37              True              True                   0.845951
# 38             False              True                   0.804769
# 34             False              True                   0.798812
#
#     actual_test_accuracy_std  loss_mean  loss_std  accuracy_per_output_mean  \
# 39                  0.011821   0.350523  0.007785                  0.940083
# 35                  0.009619   0.347331  0.006256                  0.940517
# 32                  0.004022   0.348008  0.008245                  0.939364
# 33                  0.002774   0.342664  0.006333                  0.940475
# 36                  0.002633   0.343516  0.008917                  0.939868
# 37                  0.019276   0.353061  0.017318                  0.938019
# 38                  0.022700   0.426374  0.016978                  0.922201
# 34                  0.010381   0.430561  0.011949                  0.921823
#
#     accuracy_per_output_std  table_name_test_accuracy_mean  \
# 39                 0.001698                       0.944125
# 35                 0.001405                       0.951122
# 32                 0.000561                       0.953596
# 33                 0.000795                       0.956961
# 36                 0.001079                       0.954116
# 37                 0.002369                       0.943827
# 38                 0.003223                       0.896491
# 34                 0.002644                       0.890076
#
#     table_name_test_accuracy_std  pageid_test_accuracy_mean  \
# 39                      0.009336                   0.868407
# 35                      0.003423                   0.862856
# 32                      0.003302                   0.860917
# 33                      0.000163                   0.856014
# 36                      0.002573                   0.855211
# 37                      0.019510                   0.857377
# 38                      0.017525                   0.838872
# 34                      0.013579                   0.838327
#
#     pageid_test_accuracy_std  padding_test_accuracy_mean  \
# 39                  0.009930                    0.989382
# 35                  0.008581                    0.989361
# 32                  0.001118                    0.989459
# 33                  0.003061                    0.989505
# 36                  0.002589                    0.989582
# 37                  0.002617                    0.989613
# 38                  0.014023                    0.987946
# 34                  0.008001                    0.987154
#
#     padding_test_accuracy_std
# 39                   0.000216
# 35                   0.000102
# 32                   0.000082
# 33                   0.000157
# 36                   0.000050
# 37                   0.000089
# 38                   0.000286
# 34                   0.000624

# %%
df_clean[df_clean['train_data_percent_used'] == 0.8].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization  \
# 31  transformer                      0.8         char
# 27  transformer                      0.8         char
# 28  transformer                      0.8         char
# 25  transformer                      0.8         char
# 29  transformer                      0.8         char
# 24  transformer                      0.8         char
# 26  transformer                      0.8         char
# 30  transformer                      0.8         char
#
#               experiment_name  add_start_end_tokens  add_row_id  \
# 31  exp-5-large/char_se_r_lr_                  True        True
# 27     exp-5-large/char_r_lr_                 False        True
# 28       exp-5-large/char_se_                  True       False
# 25       exp-5-large/char_lr_                 False       False
# 29    exp-5-large/char_se_lr_                  True       False
# 24          exp-5-large/char_                 False       False
# 26        exp-5-large/char_r_                 False        True
# 30     exp-5-large/char_se_r_                  True        True
#
#     add_label_tokens  token_length_seq  actual_test_accuracy_mean  \
# 31              True              True                   0.865182
# 27              True              True                   0.855505
# 28             False              True                   0.855088
# 25              True              True                   0.854116
# 29              True              True                   0.853704
# 24             False              True                   0.852294
# 26             False              True                   0.787596
# 30             False              True                   0.785096
#
#     actual_test_accuracy_std  loss_mean  loss_std  accuracy_per_output_mean  \
# 31                  0.008875   0.349441  0.006880                  0.941310
# 27                  0.008697   0.347755  0.006306                  0.940331
# 28                  0.004888   0.341793  0.010537                  0.940665
# 25                  0.002664   0.347276  0.008311                  0.940344
# 29                  0.010583   0.353531  0.011714                  0.939401
# 24                  0.013634   0.353444  0.007011                  0.938480
# 26                  0.015611   0.439584  0.007932                  0.920142
# 30                  0.022780   0.426619  0.009316                  0.919911
#
#     accuracy_per_output_std  table_name_test_accuracy_mean  \
# 31                 0.001308                       0.948364
# 27                 0.001342                       0.950916
# 28                 0.001543                       0.954682
# 25                 0.000665                       0.956709
# 29                 0.001204                       0.950736
# 24                 0.001860                       0.948611
# 26                 0.001966                       0.883038
# 30                 0.003436                       0.884973
#
#     table_name_test_accuracy_std  pageid_test_accuracy_mean  \
# 31                      0.003783                   0.870434
# 27                      0.003339                   0.860140
# 28                      0.002129                   0.855422
# 25                      0.000621                   0.854805
# 29                      0.011201                   0.858432
# 24                      0.013823                   0.859960
# 26                      0.019081                   0.831197
# 30                      0.019727                   0.826824
#
#     pageid_test_accuracy_std  padding_test_accuracy_mean  \
# 31                  0.008441                    0.989387
# 27                  0.007848                    0.989505
# 28                  0.004873                    0.990215
# 25                  0.002678                    0.989510
# 29                  0.001612                    0.989623
# 24                  0.000686                    0.989387
# 26                  0.011557                    0.987653
# 30                  0.020244                    0.987921
#
#     padding_test_accuracy_std
# 31                   0.000221
# 27                   0.000166
# 28                   0.001515
# 25                   0.000066
# 29                   0.000064
# 24                   0.000182
# 26                   0.000398
# 30                   0.000322

# %%
df_clean[df_clean['train_data_percent_used'] == 0.6].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization  \
# 23  transformer                      0.6         char
# 20  transformer                      0.6         char
# 17  transformer                      0.6         char
# 19  transformer                      0.6         char
# 16  transformer                      0.6         char
# 21  transformer                      0.6         char
# 22  transformer                      0.6         char
# 18  transformer                      0.6         char
#
#               experiment_name  add_start_end_tokens  add_row_id  \
# 23  exp-5-large/char_se_r_lr_                  True        True
# 20       exp-5-large/char_se_                  True       False
# 17       exp-5-large/char_lr_                 False       False
# 19     exp-5-large/char_r_lr_                 False        True
# 16          exp-5-large/char_                 False       False
# 21    exp-5-large/char_se_lr_                  True       False
# 22     exp-5-large/char_se_r_                  True        True
# 18        exp-5-large/char_r_                 False        True
#
#     add_label_tokens  token_length_seq  actual_test_accuracy_mean  \
# 23              True              True                   0.858350
# 20             False              True                   0.856127
# 17              True              True                   0.854244
# 19              True              True                   0.851698
# 16             False              True                   0.851091
# 21              True              True                   0.833491
# 22             False              True                   0.762784
# 18             False              True                   0.750031
#
#     actual_test_accuracy_std  loss_mean  loss_std  accuracy_per_output_mean  \
# 23                  0.009671   0.358756  0.005499                  0.939905
# 20                  0.002238   0.346799  0.012344                  0.940487
# 17                  0.002353   0.348985  0.006618                  0.940384
# 19                  0.010240   0.358257  0.009352                  0.939202
# 16                  0.008979   0.353261  0.008078                  0.938306
# 21                  0.035302   0.365257  0.011475                  0.936363
# 22                  0.013292   0.445122  0.013842                  0.916470
# 18                  0.025652   0.470420  0.027493                  0.909836
#
#     accuracy_per_output_std  table_name_test_accuracy_mean  \
# 23                 0.001276                       0.944747
# 20                 0.001005                       0.954666
# 17                 0.000921                       0.956446
# 19                 0.001896                       0.947284
# 16                 0.001312                       0.948246
# 21                 0.004814                       0.930075
# 22                 0.001623                       0.871792
# 18                 0.010020                       0.874684
#
#     table_name_test_accuracy_std  pageid_test_accuracy_mean  \
# 23                      0.004092                   0.866288
# 20                      0.003112                   0.856672
# 17                      0.000484                   0.855263
# 19                      0.010591                   0.858478
# 16                      0.009004                   0.858442
# 21                      0.036034                   0.858257
# 22                      0.022914                   0.811956
# 18                      0.016745                   0.785467
#
#     pageid_test_accuracy_std  padding_test_accuracy_mean  \
# 23                  0.008111                    0.989238
# 20                  0.002263                    0.990020
# 17                  0.002876                    0.989639
# 19                  0.006036                    0.989294
# 16                  0.000878                    0.989366
# 21                  0.002398                    0.989526
# 22                  0.019966                    0.987751
# 18                  0.027625                    0.986953
#
#     padding_test_accuracy_std
# 23                   0.000178
# 20                   0.001429
# 17                   0.000520
# 19                   0.000182
# 16                   0.000142
# 21                   0.000133
# 22                   0.000267
# 18                   0.000618

# %%
df_clean[df_clean['train_data_percent_used'] == 0.4].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization  \
# 12  transformer                      0.4         char
# 15  transformer                      0.4         char
# 11  transformer                      0.4         char
# 9   transformer                      0.4         char
# 8   transformer                      0.4         char
# 13  transformer                      0.4         char
# 14  transformer                      0.4         char
# 10  transformer                      0.4         char
#
#               experiment_name  add_start_end_tokens  add_row_id  \
# 12       exp-5-large/char_se_                  True       False
# 15  exp-5-large/char_se_r_lr_                  True        True
# 11     exp-5-large/char_r_lr_                 False        True
# 9        exp-5-large/char_lr_                 False       False
# 8           exp-5-large/char_                 False       False
# 13    exp-5-large/char_se_lr_                  True       False
# 14     exp-5-large/char_se_r_                  True        True
# 10        exp-5-large/char_r_                 False        True
#
#     add_label_tokens  token_length_seq  actual_test_accuracy_mean  \
# 12             False              True                   0.855098
# 15              True              True                   0.852968
# 11              True              True                   0.851430
# 9               True              True                   0.851147
# 8              False              True                   0.847767
# 13              True              True                   0.831197
# 14             False              True                   0.699486
# 10             False              True                   0.674437
#
#     actual_test_accuracy_std  loss_mean  loss_std  accuracy_per_output_mean  \
# 12                  0.002583   0.352106  0.015328                  0.940643
# 15                  0.014414   0.365698  0.006413                  0.939064
# 11                  0.004836   0.360150  0.006102                  0.939672
# 9                   0.007020   0.357248  0.008895                  0.939931
# 8                   0.007457   0.359695  0.006782                  0.937687
# 13                  0.031563   0.368012  0.015235                  0.936075
# 14                  0.023398   0.502553  0.022693                  0.897838
# 10                  0.020001   0.537220  0.018746                  0.889305
#
#     accuracy_per_output_std  table_name_test_accuracy_mean  \
# 12                 0.000707                       0.956672
# 15                 0.001815                       0.942540
# 11                 0.000802                       0.947860
# 9                  0.001446                       0.954867
# 8                  0.001050                       0.948560
# 13                 0.004051                       0.928208
# 14                 0.006735                       0.829679
# 10                 0.006036                       0.819179
#
#     table_name_test_accuracy_std  pageid_test_accuracy_mean  \
# 12                      0.002109                   0.855443
# 15                      0.006198                   0.862316
# 11                      0.003519                   0.858375
# 9                       0.001009                   0.852541
# 8                       0.007542                   0.854074
# 13                      0.032421                   0.857809
# 14                      0.019723                   0.740189
# 10                      0.017504                   0.729293
#
#     pageid_test_accuracy_std  padding_test_accuracy_mean  \
# 12                  0.002628                    0.989490
# 15                  0.014650                    0.989063
# 11                  0.004826                    0.989464
# 9                   0.007235                    0.989449
# 8                   0.002182                    0.989140
# 13                  0.002575                    0.989515
# 14                  0.025525                    0.987674
# 10                  0.025298                    0.986213
#
#     padding_test_accuracy_std
# 12                   0.000119
# 15                   0.000229
# 11                   0.000240
# 9                    0.000174
# 8                    0.000300
# 13                   0.000169
# 14                   0.000592
# 10                   0.000975

# %%
df_clean[df_clean['train_data_percent_used'] == 0.2].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#          model  train_data_percent_used tokenization  \
# 4  transformer                      0.2         char
# 1  transformer                      0.2         char
# 5  transformer                      0.2         char
# 0  transformer                      0.2         char
# 3  transformer                      0.2         char
# 7  transformer                      0.2         char
# 2  transformer                      0.2         char
# 6  transformer                      0.2         char
#
#              experiment_name  add_start_end_tokens  add_row_id  \
# 4       exp-5-large/char_se_                  True       False
# 1       exp-5-large/char_lr_                 False       False
# 5    exp-5-large/char_se_lr_                  True       False
# 0          exp-5-large/char_                 False       False
# 3     exp-5-large/char_r_lr_                 False        True
# 7  exp-5-large/char_se_r_lr_                  True        True
# 2        exp-5-large/char_r_                 False        True
# 6     exp-5-large/char_se_r_                  True        True
#
#    add_label_tokens  token_length_seq  actual_test_accuracy_mean  \
# 4             False              True                   0.850478
# 1              True              True                   0.848956
# 5              True              True                   0.813309
# 0             False              True                   0.779005
# 3              True              True                   0.749239
# 7              True              True                   0.581644
# 2             False              True                   0.525049
# 6             False              True                   0.418675
#
#    actual_test_accuracy_std  loss_mean  loss_std  accuracy_per_output_mean  \
# 4                  0.005139   0.371217  0.012885                  0.938912
# 1                  0.001862   0.365960  0.008204                  0.938983
# 5                  0.023209   0.379373  0.012851                  0.933116
# 0                  0.040618   0.433028  0.019538                  0.924774
# 3                  0.022117   0.418205  0.015199                  0.922603
# 7                  0.115732   0.488541  0.034114                  0.898887
# 2                  0.045514   0.764058  0.033175                  0.832287
# 6                  0.075618   0.736912  0.040674                  0.826415
#
#    accuracy_per_output_std  table_name_test_accuracy_mean  \
# 4                 0.000938                       0.954270
# 1                 0.000800                       0.951302
# 5                 0.003240                       0.912270
# 0                 0.006377                       0.891470
# 3                 0.003754                       0.876119
# 7                 0.014515                       0.866653
# 2                 0.010462                       0.667810
# 6                 0.014348                       0.699393
#
#    table_name_test_accuracy_std  pageid_test_accuracy_mean  \
# 4                      0.002629                   0.851245
# 1                      0.001374                   0.852166
# 5                      0.022897                   0.854363
# 0                      0.042320                   0.820954
# 3                      0.035045                   0.804306
# 7                      0.033599                   0.641429
# 2                      0.059039                   0.602258
# 6                      0.028330                   0.487236
#
#    pageid_test_accuracy_std  padding_test_accuracy_mean  \
# 4                  0.005090                    0.988985
# 1                  0.002522                    0.989114
# 5                  0.001505                    0.989058
# 0                  0.015635                    0.987967
# 3                  0.015351                    0.988852
# 7                  0.104493                    0.988816
# 2                  0.017990                    0.984412
# 6                  0.083080                    0.986984
#
#    padding_test_accuracy_std
# 4                   0.000107
# 1                   0.000223
# 5                   0.000206
# 0                   0.000584
# 3                   0.000456
# 7                   0.000275
# 2                   0.001131
# 6                   0.000771
