# %%
import pandas as pd

def clean_data(df):
    # Drop columns: 'data', 'epochs' and 12 other columns
    df = df.drop(columns=['data', 'epochs', 'batch_size', 'learning_rate', 'seq_length', 'test_split', 'val_split', 'vocab_size', 'patience', 'results_dir', 'shuffle', 'disable_train_shuffle', 'early_stopping', 'remove_system_tables'])
    # Sort by column: 'actual_test_accuracy_mean' (descending)
    df = df.sort_values(['actual_test_accuracy_mean'], ascending=[False])
    return df

df = pd.read_csv('../results/exp-5/results_clean.csv')

df_clean = clean_data(df.copy())

# %%
# for each train_data_percent_used, get the row with the highest actual_test_accuracy_mean
df_best_per_percent = df_clean.loc[df_clean.groupby('train_data_percent_used')['actual_test_accuracy_mean'].idxmax()]
df_best_per_percent.sort_values('train_data_percent_used', ascending=[False], inplace=True)
df_best_per_percent
# Out:
#           model  train_data_percent_used tokenization    experiment_name  \
# 37  transformer                      1.0         char  exp-5/char_se_lr_
# 29  transformer                      0.8         char  exp-5/char_se_lr_
# 21  transformer                      0.6         char  exp-5/char_se_lr_
# 13  transformer                      0.4         char  exp-5/char_se_lr_
# 5   transformer                      0.2         char  exp-5/char_se_lr_
#
#     add_start_end_tokens  add_row_id  add_label_tokens  token_length_seq  \
# 37                  True       False              True              True
# 29                  True       False              True              True
# 21                  True       False              True              True
# 13                  True       False              True              True
# 5                   True       False              True              True
#
#     actual_test_accuracy_mean  actual_test_accuracy_std  loss_mean  loss_std  \
# 37                   0.867664                  0.001389   0.254856  0.005303
# 29                   0.868302                  0.002690   0.256368  0.002346
# 21                   0.867566                  0.001969   0.262458  0.002302
# 13                   0.853288                  0.009191   0.276265  0.003985
# 5                    0.479490                  0.117683   0.421414  0.049193
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 37                  0.953916                 0.000138
# 29                  0.953930                 0.000295
# 21                  0.953803                 0.000241
# 13                  0.952326                 0.000897
# 5                   0.904774                 0.016753
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 37                       0.939352                      0.000621
# 29                       0.939156                      0.000000
# 21                       0.939352                      0.000621
# 13                       0.935672                      0.003150
# 5                        0.853729                      0.031576
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 37                   0.867664                  0.001389
# 29                   0.868302                  0.002690
# 21                   0.867566                  0.001969
# 13                   0.856771                  0.008044
# 5                    0.530569                  0.119611
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 37                         1.0                        0.0
# 29                         1.0                        0.0
# 21                         1.0                        0.0
# 13                         1.0                        0.0
# 5                          1.0                        0.0

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
df_clean[df_clean['train_data_percent_used'] == 1.0].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 37  transformer                      1.0         char    exp-5/char_se_lr_
# 33  transformer                      1.0         char       exp-5/char_lr_
# 32  transformer                      1.0         char          exp-5/char_
# 36  transformer                      1.0         char       exp-5/char_se_
# 39  transformer                      1.0         char  exp-5/char_se_r_lr_
# 35  transformer                      1.0         char     exp-5/char_r_lr_
# 38  transformer                      1.0         char     exp-5/char_se_r_
# 34  transformer                      1.0         char        exp-5/char_r_
#
#     add_start_end_tokens  add_row_id  add_label_tokens  token_length_seq  \
# 37                  True       False              True              True
# 33                 False       False              True              True
# 32                 False       False             False              True
# 36                  True       False             False              True
# 39                  True        True              True              True
# 35                 False        True              True              True
# 38                  True        True             False              True
# 34                 False        True             False              True
#
#     actual_test_accuracy_mean  actual_test_accuracy_std  loss_mean  loss_std  \
# 37                   0.867664                  0.001389   0.254856  0.005303
# 33                   0.865456                  0.002574   0.251940  0.001207
# 32                   0.864524                  0.002353   0.271920  0.008459
# 36                   0.864328                  0.002462   0.261728  0.003545
# 39                   0.830079                  0.014971   0.275054  0.005009
# 35                   0.791757                  0.021455   0.285551  0.009708
# 38                   0.763101                  0.028949   0.306074  0.015804
# 34                   0.672031                  0.014838   0.366210  0.012870
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 37                  0.953916                 0.000138
# 33                  0.953523                 0.000224
# 32                  0.952924                 0.000250
# 36                  0.953405                 0.000272
# 39                  0.950265                 0.001810
# 35                  0.944931                 0.002993
# 38                  0.940226                 0.004491
# 34                  0.924465                 0.002644
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 37                       0.939352                      0.000621
# 33                       0.939107                      0.001046
# 32                       0.937929                      0.000259
# 36                       0.938665                      0.000000
# 39                       0.929048                      0.007714
# 35                       0.934740                      0.004449
# 38                       0.916487                      0.007491
# 34                       0.880569                      0.006535
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 37                   0.867664                  0.001389
# 33                   0.865505                  0.002591
# 32                   0.864573                  0.002381
# 36                   0.864328                  0.002462
# 39                   0.838862                  0.013250
# 35                   0.795240                  0.022556
# 38                   0.775074                  0.029322
# 34                   0.692689                  0.014740
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 37                    1.000000                    0.00000
# 33                    1.000000                    0.00000
# 32                    0.999902                    0.00031
# 36                    1.000000                    0.00000
# 39                    1.000000                    0.00000
# 35                    1.000000                    0.00000
# 38                    1.000000                    0.00000
# 34                    1.000000                    0.00000

# %%
df_clean[df_clean['train_data_percent_used'] == 0.8].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 29  transformer                      0.8         char    exp-5/char_se_lr_
# 25  transformer                      0.8         char       exp-5/char_lr_
# 24  transformer                      0.8         char          exp-5/char_
# 28  transformer                      0.8         char       exp-5/char_se_
# 31  transformer                      0.8         char  exp-5/char_se_r_lr_
# 27  transformer                      0.8         char     exp-5/char_r_lr_
# 30  transformer                      0.8         char     exp-5/char_se_r_
# 26  transformer                      0.8         char        exp-5/char_r_
#
#     add_start_end_tokens  add_row_id  add_label_tokens  token_length_seq  \
# 29                  True       False              True              True
# 25                 False       False              True              True
# 24                 False       False             False              True
# 28                  True       False             False              True
# 31                  True        True              True              True
# 27                 False        True              True              True
# 30                  True        True             False              True
# 26                 False        True             False              True
#
#     actual_test_accuracy_mean  actual_test_accuracy_std  loss_mean  loss_std  \
# 29                   0.868302                  0.002690   0.256368  0.002346
# 25                   0.864328                  0.002440   0.258394  0.002882
# 24                   0.862709                  0.003491   0.271120  0.005788
# 28                   0.859470                  0.008087   0.266334  0.002166
# 31                   0.795829                  0.012708   0.294995  0.006005
# 27                   0.743572                  0.026401   0.313502  0.015852
# 30                   0.722375                  0.037361   0.330604  0.021183
# 26                   0.634593                  0.010468   0.392755  0.009445
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 29                  0.953930                 0.000295
# 25                  0.953273                 0.000252
# 24                  0.952709                 0.000466
# 28                  0.952890                 0.000760
# 31                  0.945869                 0.001522
# 27                  0.938189                 0.004253
# 30                  0.934063                 0.006055
# 26                  0.916953                 0.002316
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 29                       0.939156                      0.000000
# 25                       0.938469                      0.000662
# 24                       0.936997                      0.001780
# 28                       0.938665                      0.000000
# 31                       0.924043                      0.005991
# 27                       0.930962                      0.005255
# 30                       0.915358                      0.007997
# 26                       0.872080                      0.006032
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 29                   0.868302                  0.002690
# 25                   0.864426                  0.002459
# 24                   0.863543                  0.002517
# 28                   0.859470                  0.008087
# 31                   0.805692                  0.011919
# 27                   0.747988                  0.026827
# 30                   0.731845                  0.036586
# 26                   0.657753                  0.010291
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 29                         1.0                        0.0
# 25                         1.0                        0.0
# 24                         1.0                        0.0
# 28                         1.0                        0.0
# 31                         1.0                        0.0
# 27                         1.0                        0.0
# 30                         1.0                        0.0
# 26                         1.0                        0.0

# %%
df_clean[df_clean['train_data_percent_used'] == 0.6].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 21  transformer                      0.6         char    exp-5/char_se_lr_
# 16  transformer                      0.6         char          exp-5/char_
# 17  transformer                      0.6         char       exp-5/char_lr_
# 20  transformer                      0.6         char       exp-5/char_se_
# 23  transformer                      0.6         char  exp-5/char_se_r_lr_
# 19  transformer                      0.6         char     exp-5/char_r_lr_
# 22  transformer                      0.6         char     exp-5/char_se_r_
# 18  transformer                      0.6         char        exp-5/char_r_
#
#     add_start_end_tokens  add_row_id  add_label_tokens  token_length_seq  \
# 21                  True       False              True              True
# 16                 False       False             False              True
# 17                 False       False              True              True
# 20                  True       False             False              True
# 23                  True        True              True              True
# 19                 False        True              True              True
# 22                  True        True             False              True
# 18                 False        True             False              True
#
#     actual_test_accuracy_mean  actual_test_accuracy_std  loss_mean  loss_std  \
# 21                   0.867566                  0.001969   0.262458  0.002302
# 16                   0.856771                  0.007232   0.278907  0.005030
# 17                   0.855741                  0.007686   0.266772  0.003187
# 20                   0.855348                  0.009587   0.273682  0.005176
# 23                   0.737733                  0.017703   0.321767  0.005568
# 19                   0.657262                  0.029864   0.370715  0.024831
# 22                   0.621982                  0.019204   0.394404  0.016450
# 18                   0.521443                  0.029794   0.469797  0.018606
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 21                  0.953803                 0.000241
# 16                  0.952076                 0.000717
# 17                  0.952296                 0.000726
# 20                  0.952439                 0.001003
# 23                  0.937713                 0.002408
# 19                  0.922287                 0.006695
# 22                  0.915604                 0.004658
# 18                  0.893670                 0.005987
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 21                       0.939352                      0.000621
# 16                       0.936261                      0.001928
# 17                       0.936016                      0.003858
# 20                       0.937831                      0.002638
# 23                       0.910648                      0.008659
# 19                       0.912512                      0.009660
# 22                       0.901717                      0.006072
# 18                       0.847645                      0.006051
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 21                   0.867566                  0.001969
# 16                   0.858342                  0.007223
# 17                   0.858096                  0.006505
# 20                   0.856183                  0.008341
# 23                   0.750981                  0.017190
# 19                   0.666732                  0.029864
# 22                   0.633219                  0.020304
# 18                   0.542689                  0.031610
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 21                         1.0                        0.0
# 16                         1.0                        0.0
# 17                         1.0                        0.0
# 20                         1.0                        0.0
# 23                         1.0                        0.0
# 19                         1.0                        0.0
# 22                         1.0                        0.0
# 18                         1.0                        0.0

# %%
df_clean[df_clean['train_data_percent_used'] == 0.4].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#           model  train_data_percent_used tokenization      experiment_name  \
# 13  transformer                      0.4         char    exp-5/char_se_lr_
# 12  transformer                      0.4         char       exp-5/char_se_
# 8   transformer                      0.4         char          exp-5/char_
# 9   transformer                      0.4         char       exp-5/char_lr_
# 15  transformer                      0.4         char  exp-5/char_se_r_lr_
# 11  transformer                      0.4         char     exp-5/char_r_lr_
# 14  transformer                      0.4         char     exp-5/char_se_r_
# 10  transformer                      0.4         char        exp-5/char_r_
#
#     add_start_end_tokens  add_row_id  add_label_tokens  token_length_seq  \
# 13                  True       False              True              True
# 12                  True       False             False              True
# 8                  False       False             False              True
# 9                  False       False              True              True
# 15                  True        True              True              True
# 11                 False        True              True              True
# 14                  True        True             False              True
# 10                 False        True             False              True
#
#     actual_test_accuracy_mean  actual_test_accuracy_std  loss_mean  loss_std  \
# 13                   0.853288                  0.009191   0.276265  0.003985
# 12                   0.818695                  0.022380   0.299773  0.007271
# 8                    0.817026                  0.032697   0.299863  0.008985
# 9                    0.806428                  0.021200   0.288428  0.005168
# 15                   0.582385                  0.029494   0.407943  0.014097
# 11                   0.568302                  0.019409   0.465907  0.013107
# 14                   0.475074                  0.029325   0.526127  0.023729
# 10                   0.349853                  0.035729   0.619692  0.019202
#
#     accuracy_per_output_mean  accuracy_per_output_std  \
# 13                  0.952326                 0.000897
# 12                  0.948641                 0.002281
# 8                   0.948057                 0.003350
# 9                   0.947360                 0.002217
# 15                  0.910334                 0.006165
# 11                  0.899460                 0.004201
# 14                  0.880638                 0.007485
# 10                  0.850702                 0.006528
#
#     table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 13                       0.935672                      0.003150
# 12                       0.938469                      0.000621
# 8                        0.934789                      0.004799
# 9                        0.932237                      0.005881
# 15                       0.884642                      0.005621
# 11                       0.880373                      0.007771
# 14                       0.869136                      0.021554
# 10                       0.813248                      0.010748
#
#     pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 13                   0.856771                  0.008044
# 12                   0.818891                  0.022348
# 8                    0.820020                  0.030222
# 9                    0.812610                  0.022059
# 15                   0.597203                  0.033793
# 11                   0.577969                  0.019058
# 14                   0.489107                  0.027181
# 10                   0.371344                  0.036840
#
#     padding_test_accuracy_mean  padding_test_accuracy_std
# 13                         1.0                        0.0
# 12                         1.0                        0.0
# 8                          1.0                        0.0
# 9                          1.0                        0.0
# 15                         1.0                        0.0
# 11                         1.0                        0.0
# 14                         1.0                        0.0
# 10                         1.0                        0.0

# %%
df_clean[df_clean['train_data_percent_used'] == 0.2].sort_values('actual_test_accuracy_mean', ascending=[False])
# Out:
#          model  train_data_percent_used tokenization      experiment_name  \
# 5  transformer                      0.2         char    exp-5/char_se_lr_
# 1  transformer                      0.2         char       exp-5/char_lr_
# 4  transformer                      0.2         char       exp-5/char_se_
# 3  transformer                      0.2         char     exp-5/char_r_lr_
# 0  transformer                      0.2         char          exp-5/char_
# 6  transformer                      0.2         char     exp-5/char_se_r_
# 7  transformer                      0.2         char  exp-5/char_se_r_lr_
# 2  transformer                      0.2         char        exp-5/char_r_
#
#    add_start_end_tokens  add_row_id  add_label_tokens  token_length_seq  \
# 5                  True       False              True              True
# 1                 False       False              True              True
# 4                  True       False             False              True
# 3                 False        True              True              True
# 0                 False       False             False              True
# 6                  True        True             False              True
# 7                  True        True              True              True
# 2                 False        True             False              True
#
#    actual_test_accuracy_mean  actual_test_accuracy_std  loss_mean  loss_std  \
# 5                   0.479490                  0.117683   0.421414  0.049193
# 1                   0.319038                  0.064127   0.481484  0.034819
# 4                   0.265015                  0.049326   0.533453  0.030066
# 3                   0.250442                  0.037609   0.719298  0.033108
# 0                   0.202601                  0.066298   0.591464  0.060561
# 6                   0.109372                  0.028483   0.871068  0.045787
# 7                   0.084887                  0.031743   0.893959  0.084334
# 2                   0.033317                  0.012636   1.132951  0.044156
#
#    accuracy_per_output_mean  accuracy_per_output_std  \
# 5                  0.904774                 0.016753
# 1                  0.885235                 0.009655
# 4                  0.864642                 0.010563
# 3                  0.823901                 0.007554
# 0                  0.851011                 0.016047
# 6                  0.783548                 0.009148
# 7                  0.774760                 0.018041
# 2                  0.732664                 0.008291
#
#    table_name_test_accuracy_mean  table_name_test_accuracy_std  \
# 5                       0.853729                      0.031576
# 1                       0.833464                      0.045964
# 4                       0.930128                      0.006216
# 3                       0.818253                      0.023845
# 0                       0.818940                      0.040226
# 6                       0.797056                      0.025015
# 7                       0.844406                      0.021904
# 2                       0.723209                      0.023766
#
#    pageid_test_accuracy_mean  pageid_test_accuracy_std  \
# 5                   0.530569                  0.119611
# 1                   0.361629                  0.067109
# 4                   0.268204                  0.049403
# 3                   0.260157                  0.041510
# 0                   0.227576                  0.071296
# 6                   0.117370                  0.030637
# 7                   0.086163                  0.032068
# 2                   0.039647                  0.015568
#
#    padding_test_accuracy_mean  padding_test_accuracy_std
# 5                    1.000000                   0.000000
# 1                    1.000000                   0.000000
# 4                    1.000000                   0.000000
# 3                    0.999853                   0.000465
# 0                    1.000000                   0.000000
# 6                    1.000000                   0.000000
# 7                    1.000000                   0.000000
# 2                    0.999558                   0.000711
